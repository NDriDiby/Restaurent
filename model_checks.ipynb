# %%
from start_django import init_django

# %%
init_django("Restaurent")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/ndridiby/Desktop/NOVA CLOUD AI/Restaurent/model_checks.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/model_checks.ipynb#ch0000001?line=0'>1</a> init_django("Restaurent")
#
# File ~/Desktop/NOVA CLOUD AI/Restaurent/start_django.py:25, in init_django(project_name)
#      <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/start_django.py?line=22'>23</a> os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
#      <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/start_django.py?line=23'>24</a> import django
# ---> <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/start_django.py?line=24'>25</a> django.setup()
#
# File ~/Library/Python/3.8/lib/python/site-packages/django/__init__.py:19, in setup(set_prefix)
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/__init__.py?line=15'>16</a> from django.urls import set_script_prefix
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/__init__.py?line=16'>17</a> from django.utils.log import configure_logging
# ---> <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/__init__.py?line=18'>19</a> configure_logging(settings.LOGGING_CONFIG, settings.LOGGING)
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/__init__.py?line=19'>20</a> if set_prefix:
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/__init__.py?line=20'>21</a>     set_script_prefix(
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/__init__.py?line=21'>22</a>         "/" if settings.FORCE_SCRIPT_NAME is None else settings.FORCE_SCRIPT_NAME
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/__init__.py?line=22'>23</a>     )
#
# File ~/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py:92, in LazySettings.__getattr__(self, name)
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=89'>90</a> """Return the value of a setting and cache it in self.__dict__."""
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=90'>91</a> if (_wrapped := self._wrapped) is empty:
# ---> <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=91'>92</a>     self._setup(name)
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=92'>93</a>     _wrapped = self._wrapped
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=93'>94</a> val = getattr(_wrapped, name)
#
# File ~/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py:79, in LazySettings._setup(self, name)
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=70'>71</a>     desc = ("setting %s" % name) if name else "settings"
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=71'>72</a>     raise ImproperlyConfigured(
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=72'>73</a>         "Requested %s, but settings are not configured. "
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=73'>74</a>         "You must either define the environment variable %s "
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=74'>75</a>         "or call settings.configure() before accessing settings."
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=75'>76</a>         % (desc, ENVIRONMENT_VARIABLE)
#      <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=76'>77</a>     )
# ---> <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=78'>79</a> self._wrapped = Settings(settings_module)
#
# File ~/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py:190, in Settings.__init__(self, settings_module)
#     <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=186'>187</a> # store the settings module in case someone later cares
#     <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=187'>188</a> self.SETTINGS_MODULE = settings_module
# --> <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=189'>190</a> mod = importlib.import_module(self.SETTINGS_MODULE)
#     <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=191'>192</a> tuple_settings = (
#     <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=192'>193</a>     "ALLOWED_HOSTS",
#     <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=193'>194</a>     "INSTALLED_APPS",
#    (...)
#     <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=196'>197</a>     "SECRET_KEY_FALLBACKS",
#     <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=197'>198</a> )
#     <a href='file:///Users/ndridiby/Library/Python/3.8/lib/python/site-packages/django/conf/__init__.py?line=198'>199</a> self._explicit_settings = set()
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     <a href='file:///Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/importlib/__init__.py?line=124'>125</a>             break
#     <a href='file:///Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/importlib/__init__.py?line=125'>126</a>         level += 1
# --> <a href='file:///Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/importlib/__init__.py?line=126'>127</a> return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:783, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:219, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Desktop/NOVA CLOUD AI/Restaurent/Restaurent/settings.py:15, in <module>
#      <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/Restaurent/settings.py?line=12'>13</a> from pathlib import Path
#      <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/Restaurent/settings.py?line=13'>14</a> import os
# ---> <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/Restaurent/settings.py?line=14'>15</a> import redis
#      <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/Restaurent/settings.py?line=18'>19</a> # Build paths inside the project like this: BASE_DIR / 'subdir'.
#      <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/Restaurent/settings.py?line=19'>20</a> #BASE_DIR = Path(__file__).resolve().parent.parent
#      <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/Restaurent/settings.py?line=20'>21</a> #BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#      <a href='file:///Users/ndridiby/Desktop/NOVA%20CLOUD%20AI/Restaurent/Restaurent/settings.py?line=21'>22</a> BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#
# ModuleNotFoundError: No module named 'redis'

# %%
from Resto.models import ItemChoices,ItemChoiceCategory,IventoryItemCategory,IventoryItem,Accompagement,Item

# %%
#10
#4
choice = ItemChoices.objects.filter(parent_food_id=10)
print(choice)
# Out:
# <QuerySet [<ItemChoices: Piment>, <ItemChoices: Rare>, <ItemChoices: Medium>, <ItemChoices: Well Done>, <ItemChoices: Tomatoes>, <ItemChoices: Oignons>]>

# %%
cat_choice = ItemChoiceCategory.objects.filter(item_id = 10)
print(cat_choice)
# Out:
# <QuerySet [<ItemChoiceCategory: Assaisonement>, <ItemChoiceCategory: Cuisson>]>

# %%
for cat in cat_choice:
    print(cat)
    for c in choice:
        if c.choice_category == cat:
            print(cat.itemchoices_set.all())
# Out:
# Assaisonement
# <QuerySet [<ItemChoices: Piment>, <ItemChoices: Piment>]>
# Cuisson
# <QuerySet [<ItemChoices: Rare>, <ItemChoices: Medium>, <ItemChoices: Well Done>]>
# <QuerySet [<ItemChoices: Rare>, <ItemChoices: Medium>, <ItemChoices: Well Done>]>
# <QuerySet [<ItemChoices: Rare>, <ItemChoices: Medium>, <ItemChoices: Well Done>]>

# %%
inv = IventoryItemCategory.objects.get(id=1)
inv
# Out:
# <IventoryItemCategory: Legumes>

# %%
inv.iventoryitem_set.all()
# Out:
# <QuerySet [<IventoryItem: Tomatoes>, <IventoryItem: Carrote>, <IventoryItem: Oignons>]>

# %%
acc = Accompagement.objects.all()

# %%
for i in range(0,len(acc)):
    print(acc[i],acc[i].item_set.all())
# Out:
# Alloco <QuerySet [<Item: Ribs O Ribs>, <Item: Steack De Fillet De Boeuf>]>
# Frites <QuerySet [<Item: Poulet Texan>, <Item: Tacos>, <Item: Fillet Poulet>]>

# %%
item  = Item.objects.get(id=2)
print(item.name)
# Out:
# Fillet Poulet

# %%
print(item.accompagement.all())
# Out:
# <QuerySet [<Accompagement: Frites>]>
