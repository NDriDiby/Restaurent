# %%
from start_django import init_django

# %%
init_django("Restaurent")

# %%
from Resto.models import ItemChoices,ItemChoiceCategory

# %%
#10
#4
choice = ItemChoices.objects.filter(parent_food_id=10)
print(choice)
# Out:
# <QuerySet [<ItemChoices: Piment>, <ItemChoices: Rare>, <ItemChoices: Medium>, <ItemChoices: Well Done>]>

# %%
cat_choice = ItemChoiceCategory.objects.filter(item_id = 10)
print(cat_choice)
# Out:
# <QuerySet [<ItemChoiceCategory: Assaisonement>, <ItemChoiceCategory: Cuisson>]>

# %%
for cat in cat_choice:
    print(cat)
    for c in choice:
        if c.choice_category == cat:
            print(cat.itemchoices_set.all())
# Out:
# Assaisonement
# <QuerySet [<ItemChoices: Piment>, <ItemChoices: Piment>]>
# Cuisson
# <QuerySet [<ItemChoices: Rare>, <ItemChoices: Medium>, <ItemChoices: Well Done>]>
# <QuerySet [<ItemChoices: Rare>, <ItemChoices: Medium>, <ItemChoices: Well Done>]>
# <QuerySet [<ItemChoices: Rare>, <ItemChoices: Medium>, <ItemChoices: Well Done>]>

# %%
import pyqrcode
import png
from pyqrcode import QRCode
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/ws/w8bb_hd53djfgqkkhlf_q80w0000gn/T/ipykernel_6138/3855237486.py in <module>
#       1 import pyqrcode
# ----> 2 import png
#       3 from pyqrcode import QRCode
#
# ModuleNotFoundError: No module named 'png'

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement png (from versions: none)
# ERROR: No matching distribution found for png
